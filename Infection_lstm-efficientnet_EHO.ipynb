# %%
import os
import zipfile as zf

# Path to the repaired ZIP file
zip_file_path = "PartB_DFU_dataset - Copy.zip"
extract_path = "DFU_dataset"

if os.path.exists(zip_file_path):
    try:
        with zf.ZipFile(zip_file_path, 'r') as files:
            files.extractall(extract_path)
        print(f"Extraction completed successfully to '{extract_path}'")
    except zf.BadZipFile:
        print("Error: The ZIP file is corrupted.")
    except OSError as e:
        print(f"OS error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
else:
    print(f"Error: The file '{zip_file_path}' does not exist.")
# Out:
# Extraction completed successfully to 'DFU_dataset'

# %%
import numpy as np # linear algebra
import os
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np
from PIL import Image
# Define the root directory where your image folders are located
root_directory = "DFU_dataset/PartB_DFU_dataset - Copy"

# Initialize lists to store image paths and corresponding class labels for both datasets
image_paths_ischaemia = []
categories_ischaemia = []
image_paths_infection = []
categories_infection = []

# Iterate over each class and its subdirectories
for class_name in ["Infection", "Ischaemia"]:
    for augmentation_type in ["Aug-Negative", "Aug-Positive"]:
        folder_path = os.path.join(root_directory, class_name, augmentation_type)
        category = f"{class_name.lower()}{'pov' if 'Positive' in augmentation_type else 'neg'}"
        
        # Iterate over image files in the current directory
        for file_name in os.listdir(folder_path):
            if file_name.endswith(".jpg"):  # Assuming images are jpg format
                image_path = os.path.join(folder_path, file_name)
                if class_name == "Ischaemia":
                    image_paths_ischaemia.append(image_path)
                    categories_ischaemia.append("ischemia" if "Positive" in augmentation_type else "non-ischemia")
                elif class_name == "Infection":
                    image_paths_infection.append(image_path)
                    categories_infection.append("infection" if "Positive" in augmentation_type else "non-infection")

# Create DataFrames for each dataset
df_ischaemia = pd.DataFrame({"category": categories_ischaemia, "image_path": image_paths_ischaemia})
df_infection = pd.DataFrame({"category": categories_infection, "image_path": image_paths_infection})

# Label encoding for Ischaemia dataset
label_encoder_ischaemia = LabelEncoder()
df_ischaemia['Class_Label'] = label_encoder_ischaemia.fit_transform(df_ischaemia['category'])
print("Ischaemia Class Mapping:")
for class_label, numerical_label in zip(df_ischaemia['category'].unique(), df_ischaemia['Class_Label'].unique()):
    print(f"{class_label}: {numerical_label}")

# Label encoding for Infection dataset
label_encoder_infection = LabelEncoder()
df_infection['Class_Label'] = label_encoder_infection.fit_transform(df_infection['category'])
print("Infection Class Mapping:")
for class_label, numerical_label in zip(df_infection['category'].unique(), df_infection['Class_Label'].unique()):
    print(f"{class_label}: {numerical_label}")

# Shuffle both DataFrames
df_ischaemia = df_ischaemia.sample(frac=1).reset_index(drop=True)
df_infection = df_infection.sample(frac=1).reset_index(drop=True)

# Helper function to load and process images
def load_images(df):
    images = []
    target_labels = []   
    for index, row in df.iterrows():
        image = Image.open(row['image_path'])
        image_array = np.array(image.resize((224, 224)))  # Resize image to fit MobileNet input size
        images.append(image_array)
        target_labels.append(row['Class_Label'])
    return np.array(images), np.array(target_labels)

# Load images for both datasets
images_ischaemia, target_labels_ischaemia = load_images(df_ischaemia)
images_infection, target_labels_infection = load_images(df_infection)

print("Shape of Ischaemia images array:", images_ischaemia.shape)
print("Shape of Ischaemia target labels array:", target_labels_ischaemia.shape)
print("Shape of Infection images array:", images_infection.shape)
print("Shape of Infection target labels array:", target_labels_infection.shape)

# Split the Ischaemia dataset
X_train_ischaemia, X_test_ischaemia, y_train_ischaemia, y_test_ischaemia = train_test_split(
    images_ischaemia, target_labels_ischaemia, test_size=0.3, random_state=42)
X_val_ischaemia, X_test_ischaemia, y_val_ischaemia, y_test_ischaemia = train_test_split(
    X_test_ischaemia, y_test_ischaemia, test_size=0.25, random_state=42)  # 0.25 * 0.3 = 0.075

# Split the Infection dataset
X_train_infection, X_test_infection, y_train_infection, y_test_infection = train_test_split(
    images_infection, target_labels_infection, test_size=0.3, random_state=42)
X_val_infection, X_test_infection, y_val_infection, y_test_infection = train_test_split(
    X_test_infection, y_test_infection, test_size=0.25, random_state=42)  # 0.25 * 0.3 = 0.075

print("Ischaemia Training set shape:", X_train_ischaemia.shape, y_train_ischaemia.shape)
print("Ischaemia Validation set shape:", X_val_ischaemia.shape, y_val_ischaemia.shape)
print("Ischaemia Test set shape:", X_test_ischaemia.shape, y_test_ischaemia.shape)
print("Infection Training set shape:", X_train_infection.shape, y_train_infection.shape)
print("Infection Validation set shape:", X_val_infection.shape, y_val_infection.shape)
print("Infection Test set shape:", X_test_infection.shape, y_test_infection.shape)
# Out:
# Ischaemia Class Mapping:
# non-ischemia: 1
# ischemia: 0
# Infection Class Mapping:
# non-infection: 1
# infection: 0
# Shape of Ischaemia images array: (9870, 224, 224, 3)
# Shape of Ischaemia target labels array: (9870,)
# Shape of Infection images array: (5890, 224, 224, 3)
# Shape of Infection target labels array: (5890,)
# Ischaemia Training set shape: (6909, 224, 224, 3) (6909,)
# Ischaemia Validation set shape: (2220, 224, 224, 3) (2220,)
# Ischaemia Test set shape: (741, 224, 224, 3) (741,)
# Infection Training set shape: (4123, 224, 224, 3) (4123,)
# Infection Validation set shape: (1325, 224, 224, 3) (1325,)
# Infection Test set shape: (442, 224, 224, 3) (442,)

# %%
############################################################################
# ELEPHANT HERDING OPTIMIZATION (EHO) Algorithm Implementation
############################################################################

def initial_variables(size, min_values, max_values, target_function, start_init=None):
    dim = len(min_values)
    
    if start_init is not None:
        start_init = np.atleast_2d(start_init)
        n_rows = size - start_init.shape[0]
        if n_rows > 0:
            rows = np.random.uniform(min_values, max_values, (n_rows, dim))
            start_init = np.vstack((start_init[:, :dim], rows))
        else:
            start_init = start_init[:size, :dim]
        
        fitness_values = np.array([target_function(ind) for ind in start_init])
        # Ensure fitness_values is a 2D array for concatenation
        if fitness_values.ndim == 1:
            fitness_values = fitness_values.reshape(-1, 1)
        print(f"Shape of start_init: {start_init.shape}")
        print(f"Shape of fitness_values: {fitness_values.shape}")
        population = np.hstack((start_init, fitness_values))
    else:
        population = np.random.uniform(min_values, max_values, (size, dim))
        fitness_values = np.array([target_function(ind) for ind in population])
        # Ensure fitness_values is a 2D array for concatenation
        if fitness_values.ndim == 1:
            fitness_values = fitness_values.reshape(-1, 1)
        print(f"Shape of population: {population.shape}")
        print(f"Shape of fitness_values: {fitness_values.shape}")
        population = np.hstack((population, fitness_values))
    
    return population



def update_herd(population, alpha, beta, best_elephant, idx_b, idx_w, min_values, max_values, target_function):
    old_population = np.copy(population)
    cut = population.shape[0]
    dim = len(min_values)
    for i in range(0, cut):
        if i != idx_b and i != idx_w:
            r = np.random.rand(dim)
            population[i, :-1] = np.clip(old_population[i, :-1] + alpha * (best_elephant[:-1] - old_population[i, :-1]) * r, min_values, max_values)
        elif i == idx_b:
            center = np.mean(old_population[:, :-1], axis=0)
            population[i, :-1] = np.clip(beta * center, min_values, max_values)
        elif i == idx_w:
            random_values = np.random.rand(dim)
            population[i, :-1] = np.clip(min_values + (max_values - min_values) * random_values, min_values, max_values)
    
    # Calculate fitness values
    fitness_values = np.array([target_function(ind) for ind in population[:, :-1]])
    population[:, -1] = fitness_values
    
    idx_b = np.argmin(population[:, -1])
    idx_w = np.argmax(population[:, -1])
    if population[idx_b, -1] < best_elephant[-1]:
        best_elephant = np.copy(population[idx_b, :])
    return population, best_elephant, idx_b, idx_w


# Function: EHO
def elephant_herding_optimization(size=50, alpha=0.5, beta=0.1, min_values=[0.0001], max_values=[0.01], generations=5000, target_function=target_function, verbose=True, start_init=None, target_value=None):
    population = initial_variables(size, min_values, max_values, target_function, start_init)
    idx_b = np.argmin(population[:, -1])
    idx_w = np.argmax(population[:, -1])
    best_elephant = population[idx_b, :-1]
    min_values = np.array(min_values)
    max_values = np.array(max_values)
    count = 0
    while count <= generations:
        if verbose:    
            print('Generation: ', count, ' f(x) = ', best_elephant[-1])
        population, best_elephant, idx_b, idx_w = update_herd(population, alpha, beta, best_elephant, idx_b, idx_w, min_values, max_values, target_function)
        if target_value is not None:
            if best_elephant[-1] <= target_value:
                count = 2 * generations
            else:
                count = count + 1
        else:
            count = count + 1
    return best_elephant

############################################################################

# %%
import numpy as np
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.layers import Dropout, TimeDistributed, Flatten, LSTM, Dense, BatchNormalization
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow import keras
import os

# Suppress most TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Disable layout optimization to prevent layout warnings
tf.config.optimizer.set_experimental_options({'layout_optimizer': False})

# Define the CNN-LSTM model with specific layers set as trainable
def build_cnn_lstm_model(hp):
    base_model = EfficientNetB7(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
    
    # Freeze all layers except the last 10
    for layer in base_model.layers[:-10]:
        layer.trainable = False

    model = Sequential([
        base_model,
        TimeDistributed(Flatten()),  # Flatten the output for LSTM input
        LSTM(64, dropout=0.3, return_sequences=True),  # First LSTM layer
        LSTM(32, dropout=0.2, return_sequences=True),  # Second LSTM layer
        LSTM(16, dropout=0.2, return_sequences=False),
        Dense(128, activation='relu'),
        Dropout(0.4),
        BatchNormalization(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        BatchNormalization(),
        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(2, activation='softmax')  # Assuming binary classification
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=hp['learning_rate']),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# Example hyperparameter tuning setup for learning rate and batch size
def target_function(hyperparams):
    learning_rate = hyperparams[0]
    batch_size = int(hyperparams[1])
    
    hp = {'learning_rate': float(learning_rate)}
    model = build_cnn_lstm_model(hp)
    
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
    reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=1e-6)
    
    # Train the model with the specified batch size
    history = model.fit(
        X_train_infection, y_train_infection,
        batch_size=batch_size,
        epochs=10,
        validation_data=(X_val_infection, y_val_infection),
        callbacks=[early_stopping, reduce_lr],
        verbose=0
    )
    
    # Return validation loss as the target function metric
    val_loss = min(history.history['val_loss'])
    return val_loss

# Define the new ranges for learning rate and batch size
min_values = [0.0001, 8]  # min learning rate and batch size
max_values = [0.01, 128]  # max learning rate and batch size

# Use the EHO algorithm or other tuning methods to explore these hyperparameters
population = initial_variables(3, min_values, max_values, target_function)
print(population)
# Out:
# W0000 00:00:1729855743.380028     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.381033     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.381859     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.382628     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.383514     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.384543     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.385726     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.386865     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.387591     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.388311     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.389200     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.390308     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.391508     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.393197     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.394908     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.396593     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.398291     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.400337     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.402106     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.403713     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.406069     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.409359     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.412503     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855743.415519     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.096523     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.097302     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.098000     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.098680     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.099456     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.100341     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.101347     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.102321     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.102969     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.103627     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.104396     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.105344     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.106356     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.107767     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.109229     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.110633     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.112049     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.113761     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.115276     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.116644     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.118621     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.120981     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.123555     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729855759.126017     928 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.291360     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.292183     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.292719     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.293232     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.293787     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.294281     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.294848     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.295454     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.296127     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.296819     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.297391     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.298037     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.298726     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.299657     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.300615     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.301508     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.302470     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.303359     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.304271     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.305503     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.306581     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.307934     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.309282     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856259.310724     924 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Shape of population: (3, 2)
# Shape of fitness_values: (3, 1)
# [[4.55640477e-03 8.85711411e+01 4.52882707e-01]
#  [6.55878176e-03 5.83200273e+01 4.99483079e-01]
#  [3.94901656e-03 8.09740311e+01 4.66750115e-01]]

# %%
# Run Elephant Herding Optimization (EHO)
best_params = elephant_herding_optimization(
    size=2,  # Number of elephants
    alpha=0.2, beta=0.1, 
    min_values=min_values, max_values=max_values,
    generations=2,  # Number of generations
    target_function=target_function 
)

# Print the best found hyperparameters
print("Best Hyperparameters: ", best_params)
# Out:
# W0000 00:00:1729856491.259106     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.260208     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.261155     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.262053     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.263102     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.264318     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.265739     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.267111     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.267955     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.268872     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.269918     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.271244     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.272687     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.274723     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.276806     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.278844     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.280917     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.283410     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.285575     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.287540     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.290399     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.293773     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.297068     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856491.301035     897 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.216773     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.217467     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.218047     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.218608     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.219234     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.219942     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.220759     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.221543     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.222090     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.222661     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.223304     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.224077     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.224905     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.226046     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.227217     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.228363     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.229529     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.230904     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.232081     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.233154     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.234663     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.236428     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.238121     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856507.239736     919 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Shape of population: (2, 2)
# Shape of fitness_values: (2, 1)
# Generation:  0  f(x) =  110.41186484182302
# W0000 00:00:1729856984.658371     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.658851     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.659124     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.659443     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.659749     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.660053     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.660424     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.660744     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.661116     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.661506     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.661877     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.662271     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.662629     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.663056     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.663520     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.663962     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.664402     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.664862     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.665302     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.665801     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.666277     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.666816     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.667339     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729856984.667839     908 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.780147     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.780648     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.780948     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.781194     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.781435     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.781689     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.782042     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.782297     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.782587     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.782907     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.783198     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.783504     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.783794     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.784118     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.784452     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.784792     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.785132     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.785466     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.785801     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.786144     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.786479     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.786800     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.787106     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857017.787405     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.047778     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.048573     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.049177     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.049733     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.050363     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.051061     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.051855     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.052629     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.053193     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.053761     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.054392     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.055137     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.055932     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.057023     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.058148     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.059243     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.060351     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.061652     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.062788     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.063820     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.065279     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.067017     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.068697     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857418.070297     905 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.313518     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.313993     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.314362     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.314708     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.315052     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.315385     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.315788     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.316201     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.316643     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.317140     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.317505     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.317928     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.318368     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.318889     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.319430     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.319929     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.320454     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.320998     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.321540     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.322149     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.322749     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.323438     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.324093     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857433.324799     914 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.993576     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.994249     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.994717     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.995154     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.995627     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.996085     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.996605     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.997186     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.997792     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.998407     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.998931     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857443.999518     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.000120     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.000928     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.001740     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.002490     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.003290     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.004078     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.004880     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.005882     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.006696     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.007674     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.008647     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729857444.009679     906 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Generation:  1  f(x) =  0.42756885290145874
# W0000 00:00:1729858097.236074     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.236961     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.237660     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.238317     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.239046     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.239883     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.240940     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.241871     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.242503     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.243161     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.243903     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.244812     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.245771     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.247116     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.248471     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.249824     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.251187     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.252821     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.254233     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.255498     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.257328     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.259485     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.261577     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858097.263580     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.032225     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.032865     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.033345     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.033812     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.034285     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.034748     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.035256     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.035810     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.036408     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.037038     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.037556     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.038136     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.038746     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.039571     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.040414     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.041232     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.042103     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.042924     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.043759     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.044856     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.045821     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.046987     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.048129     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858113.049341     899 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Generation:  2  f(x) =  0.42756885290145874
# W0000 00:00:1729858345.744487     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.745773     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.746778     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.747692     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.748780     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.750026     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.751479     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.752889     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.753757     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.754629     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.755688     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.757051     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.758498     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.760573     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.762697     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.764791     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.767045     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.769758     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.772047     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.774122     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.777175     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.780851     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.784278     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729858345.788153     900 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Best Hyperparameters:  [4.65660044e-04 8.00000000e+00 4.27568853e-01]

# %%
import time
import numpy as np
from tensorflow import keras

# Extract the best hyperparameters from the EHO result
best_learning_rate = best_params[0]  # First parameter: learning rate
best_batch_size = int(best_params[1])  # Second parameter: batch size (convert to int)

# Train the CNN model using the best hyperparameters
hp_best = {'learning_rate': best_learning_rate}
model = build_cnn_lstm_model(hp_best)

# Set up callbacks for early stopping and learning rate reduction
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=1e-6)

# Measure training time
start_train_time = time.time()

# Train the model with the best hyperparameters
history = model.fit(
    X_train_infection, y_train_infection,
    epochs=20,  # You can adjust the number of epochs as needed
    batch_size=best_batch_size,
    validation_data=(X_val_infection, y_val_infection),
    callbacks=[early_stopping, reduce_lr],
    verbose=1  # Set to 1 to show training progress
)

end_train_time = time.time()  # End time for training

# Get the total training time
training_time = end_train_time - start_train_time
print(f"Total Training Time: {training_time:.2f} seconds")

# Get the metrics from the training process
train_acc = history.history['accuracy'][-1]
train_loss = history.history['loss'][-1]
val_acc = history.history['val_accuracy'][-1]
val_loss = history.history['val_loss'][-1]

# Print the training results
print("Training Accuracy: ", train_acc)
print("Training Loss: ", train_loss)
print("Validation Accuracy: ", val_acc)
print("Validation Loss: ", val_loss)

# Measure testing time
start_test_time = time.time()

# Evaluate the model on the test set (assuming you have X_test_infection and y_test_infection)
test_loss, test_acc = model.evaluate(X_test_infection, y_test_infection, verbose=1)

end_test_time = time.time()  # End time for testing

# Get the total testing time
testing_time = end_test_time - start_test_time
print(f"Total Testing Time: {testing_time:.2f} seconds")

# Print the test results
print("Test Accuracy: ", test_acc)
print("Test Loss: ", test_loss)
# Out:
# Epoch 1/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 75s 92ms/step - accuracy: 0.5402 - loss: 0.8138 - val_accuracy: 0.6204 - val_loss: 0.6514 - learning_rate: 4.6566e-04
# Epoch 2/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - accuracy: 0.6216 - loss: 0.6688 - val_accuracy: 0.7147 - val_loss: 0.5725 - learning_rate: 4.6566e-04
# Epoch 3/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 40s 78ms/step - accuracy: 0.6708 - loss: 0.6223 - val_accuracy: 0.7283 - val_loss: 0.5733 - learning_rate: 4.6566e-04
# Epoch 4/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 43s 83ms/step - accuracy: 0.7217 - loss: 0.5851 - val_accuracy: 0.7683 - val_loss: 0.5075 - learning_rate: 4.6566e-04
# Epoch 5/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.7265 - loss: 0.5613 - val_accuracy: 0.7502 - val_loss: 0.5169 - learning_rate: 4.6566e-04
# Epoch 6/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.7522 - loss: 0.5415 - val_accuracy: 0.7819 - val_loss: 0.4897 - learning_rate: 4.6566e-04
# Epoch 7/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.7601 - loss: 0.5140 - val_accuracy: 0.7962 - val_loss: 0.4749 - learning_rate: 4.6566e-04
# Epoch 8/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.7700 - loss: 0.5061 - val_accuracy: 0.7842 - val_loss: 0.4718 - learning_rate: 4.6566e-04
# Epoch 9/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.7980 - loss: 0.4552 - val_accuracy: 0.7849 - val_loss: 0.4580 - learning_rate: 4.6566e-04
# Epoch 10/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.8094 - loss: 0.4481 - val_accuracy: 0.8121 - val_loss: 0.4442 - learning_rate: 4.6566e-04
# Epoch 11/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.8327 - loss: 0.4071 - val_accuracy: 0.8257 - val_loss: 0.4280 - learning_rate: 4.6566e-04
# Epoch 12/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.8296 - loss: 0.4122 - val_accuracy: 0.8083 - val_loss: 0.4374 - learning_rate: 4.6566e-04
# Epoch 13/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 43s 83ms/step - accuracy: 0.8520 - loss: 0.3606 - val_accuracy: 0.8098 - val_loss: 0.4299 - learning_rate: 4.6566e-04
# Epoch 14/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 43s 83ms/step - accuracy: 0.8806 - loss: 0.3092 - val_accuracy: 0.8226 - val_loss: 0.4168 - learning_rate: 9.3132e-05
# Epoch 15/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.8884 - loss: 0.2895 - val_accuracy: 0.8279 - val_loss: 0.4070 - learning_rate: 9.3132e-05
# Epoch 16/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - accuracy: 0.9081 - loss: 0.2578 - val_accuracy: 0.8272 - val_loss: 0.4343 - learning_rate: 9.3132e-05
# Epoch 17/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - accuracy: 0.9129 - loss: 0.2370 - val_accuracy: 0.8362 - val_loss: 0.4114 - learning_rate: 9.3132e-05
# Epoch 18/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.9243 - loss: 0.2049 - val_accuracy: 0.8468 - val_loss: 0.4129 - learning_rate: 1.8626e-05
# Epoch 19/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - accuracy: 0.9239 - loss: 0.2162 - val_accuracy: 0.8272 - val_loss: 0.4257 - learning_rate: 1.8626e-05
# Epoch 20/20
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.9219 - loss: 0.2092 - val_accuracy: 0.8423 - val_loss: 0.4294 - learning_rate: 3.7253e-06
# Total Training Time: 870.63 seconds
# Training Accuracy:  0.9296628832817078
# Training Loss:  0.19582155346870422
# Validation Accuracy:  0.8422641754150391
# Validation Loss:  0.4293985068798065
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9062 - loss: 0.3434
# W0000 00:00:1729859957.618085     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.618854     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.619353     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.619827     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.620301     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.620781     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.621338     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.621895     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.622526     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.623168     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.623711     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.624307     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.624937     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.625740     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.626577     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.627394     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.628270     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.629099     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.629932     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.630999     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.631948     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.633128     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.634296     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859957.635534     946 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.8651 - loss: 0.3688
# Total Testing Time: 1.75 seconds
# Test Accuracy:  0.8597285151481628
# Test Loss:  0.38820788264274597
# W0000 00:00:1729859959.041940     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.042549     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.043009     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.043447     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.043910     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.044386     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.044931     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.045483     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.046078     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.046685     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.047186     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.047762     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.048354     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.049121     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.049903     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.050611     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.051365     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.052069     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.052821     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.053705     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.054490     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.055426     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.056360     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1729859959.057358     898 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
